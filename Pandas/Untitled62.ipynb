# %%
import pandas as pd

# %%
df=pd.read_csv("/content/placement - placement (1).csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0     18          6.52       1
# 1     16          5.17       0
# 2     18          8.86       1
# 3     16          7.27       1
# 4     17          7.30       1
# ..   ...           ...     ...
# 95    16          6.38       0
# 96    18          7.76       1
# 97    16          7.78       0
# 98    18          5.63       1
# 99    16          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa']+10
df
# Out:
#     cgpa  resume_score  placed
# 0     28          6.52       1
# 1     26          5.17       0
# 2     28          8.86       1
# 3     26          7.27       1
# 4     27          7.30       1
# ..   ...           ...     ...
# 95    26          6.38       0
# 96    28          7.76       1
# 97    26          7.78       0
# 98    28          5.63       1
# 99    26          6.61       0
#
# [100 rows x 3 columns]

# %%
r=df['cgpa'].mean()
r
# Out:
# np.float64(26.47)

# %%
s=df['cgpa'].median()
s
# Out:
# 26.0

# %%
g=df.filter(items=['cgpa','placed'])
g
# Out:
#     cgpa  placed
# 0     28       1
# 1     26       0
# 2     28       1
# 3     26       1
# 4     27       1
# ..   ...     ...
# 95    26       0
# 96    28       1
# 97    26       0
# 98    28       1
# 99    26       0
#
# [100 rows x 2 columns]

# %%
s=df.filter(items=[5,6],axis=0)  ## axis =0 means row wise operation
s
# Out:
#    cgpa  resume_score  placed
# 5    28          6.19       1
# 6    25          7.09       0

# %%
s=df.to_dict()
s                         # save in dict
# Out:
# {'cgpa': {0: 28,
#   1: 26,
#   2: 28,
#   3: 26,
#   4: 27,
#   5: 28,
#   6: 25,
#   7: 26,
#   8: 26,
#   9: 27,
#   10: 26,
#   11: 25,
#   12: 26,
#   13: 28,
#   14: 27,
#   15: 28,
#   16: 28,
#   17: 27,
#   18: 25,
#   19: 26,
#   20: 25,
#   21: 26,
#   22: 26,
#   23: 26,
#   24: 28,
#   25: 27,
#   26: 26,
#   27: 25,
#   28: 27,
#   29: 26,
#   30: 27,
#   31: 25,
#   32: 25,
#   33: 28,
#   34: 28,
#   35: 28,
#   36: 28,
#   37: 29,
#   38: 26,
#   39: 27,
#   40: 28,
#   41: 28,
#   42: 26,
#   43: 28,
#   44: 25,
#   45: 28,
#   46: 25,
#   47: 27,
#   48: 25,
#   49: 25,
#   50: 28,
#   51: 26,
#   52: 25,
#   53: 26,
#   54: 25,
#   55: 26,
#   56: 26,
#   57: 26,
#   58: 26,
#   59: 25,
#   60: 25,
#   61: 26,
#   62: 25,
#   63: 28,
#   64: 27,
#   65: 26,
#   66: 28,
#   67: 26,
#   68: 26,
#   69: 28,
#   70: 27,
#   71: 27,
#   72: 27,
#   73: 25,
#   74: 25,
#   75: 26,
#   76: 29,
#   77: 25,
#   78: 25,
#   79: 25,
#   80: 27,
#   81: 26,
#   82: 27,
# ...

# %%
q=df.to_string()    # save as string
q
# Out:
# '    cgpa  resume_score  placed\n0     28          6.52       1\n1     26          5.17       0\n2     28          8.86       1\n3     26          7.27       1\n4     27          7.30       1\n5     28          6.19       1\n6     25          7.09       0\n7     26          6.29       0\n8     26          6.71       0\n9     27          7.12       1\n10    26          6.35       0\n11    25          6.54       0\n12    26          7.01       0\n13    28          5.09       1\n14    27          6.25       1\n15    28          5.93       1\n16    28          7.64       1\n17    27          8.71       1\n18    25          5.88       0\n19    26          8.11       1\n20    25          8.06       0\n21    26          7.64       0\n22    26          5.77       0\n23    26          7.13       0\n24    28          6.18       1\n25    27          5.68       1\n26    26          6.47       0\n27    25          6.15       0\n28    27          7.67       1\n29    26          7.30       0\n30   
# ...

# %%
e=df.to_csv("/content/placement - placement (1).csv")
e

# %%
idx=df.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label=df.columns[0]     # first column lable
label
# Out:
# 'cgpa'

# %%
p=df.rename(columns= {'cgpa':'updated_cgpa','resume_score ':'semester_marks'})
p
# Out:
#     updated_cgpa  resume_score  placed
# 0             28          6.52       1
# 1             26          5.17       0
# 2             28          8.86       1
# 3             26          7.27       1
# 4             27          7.30       1
# ..           ...           ...     ...
# 95            26          6.38       0
# 96            28          7.76       1
# 97            26          7.78       0
# 98            28          5.63       1
# 99            26          6.61       0
#
# [100 rows x 3 columns]

# %%
# df['half']=df['cgpa'].where(df['cgpa']>7, other=0)
# df.head(10)

df['half']=df['resume_score'].where(df['resume_score']>7, other=0)
df.head(10)
# Out:
#    cgpa  resume_score  placed  half
# 0    28          6.52       1  0.00
# 1    26          5.17       0  0.00
# 2    28          8.86       1  8.86
# 3    26          7.27       1  7.27
# 4    27          7.30       1  7.30
# 5    28          6.19       1  0.00
# 6    25          7.09       0  7.09
# 7    26          6.29       0  0.00
# 8    26          6.71       0  0.00
# 9    27          7.12       1  7.12

# %%
#row=11 to 13
# column=3
# 2 column rename
# new column name -- male customer

# %%
df=pd.read_csv("/content/tips - tips (1).csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.iloc[11:14]
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4

# %%
r=df.rename(columns={'total_bill':'total_amount','tip':'add_tip'})
r
# Out:
#      total_amount  add_tip     sex smoker   day    time  size
# 0           16.99     1.01  Female     No   Sun  Dinner     2
# 1           10.34     1.66    Male     No   Sun  Dinner     3
# 2           21.01     3.50    Male     No   Sun  Dinner     3
# 3           23.68     3.31    Male     No   Sun  Dinner     2
# 4           24.59     3.61  Female     No   Sun  Dinner     4
# ..            ...      ...     ...    ...   ...     ...   ...
# 239         29.03     5.92    Male     No   Sat  Dinner     3
# 240         27.18     2.00  Female    Yes   Sat  Dinner     2
# 241         22.67     2.00    Male    Yes   Sat  Dinner     2
# 242         17.82     1.75    Male     No   Sat  Dinner     2
# 243         18.78     3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['total_bill']=df['total_bill'].astype(int)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0            16  1.01  Female     No   Sun  Dinner     2
# 1            10  1.66    Male     No   Sun  Dinner     3
# 2            21  3.50    Male     No   Sun  Dinner     3
# 3            23  3.31    Male     No   Sun  Dinner     2
# 4            24  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239          29  5.92    Male     No   Sat  Dinner     3
# 240          27  2.00  Female    Yes   Sat  Dinner     2
# 241          22  2.00    Male    Yes   Sat  Dinner     2
# 242          17  1.75    Male     No   Sat  Dinner     2
# 243          18  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['Male_customers']=df['sex'].where(df['sex']=='Male', other=0)
df['Male_customers'].replace('Male',1,inplace=True)
df
# Out:
# /tmp/ipykernel_354/1855916827.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Male_customers'].replace('Male',1,inplace=True)
# /tmp/ipykernel_354/1855916827.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Male_customers'].replace('Male',1,inplace=True)
# ...
