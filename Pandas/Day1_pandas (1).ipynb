# %%
#Pandas--> pandas is open source library which is used for handle data manipulations

# %%
import pandas as pd

# %%
# data structure of pandas::
#1 Series ---> It stores only values not column and it is one-dimensional
#2 Dataframe___ it store values with column name and it is multi-dimensional

# %%
df=pd.Series([1,45,78,90])
df
# Out:
# 0     1
# 1    45
# 2    78
# 3    90
# dtype: int64

# %%
# data frame

# %%
a={
    "Emp_ID" : [1,2,3,4,5],
    "Name"  :['sam','mohit','raj','Rahul','Aniket'],
    "Department": ['IT','Sales','IT','IT','Sales'],
    "Salary" :[20000,25000,30000,31000,26000]

}

# %%
type(a)
# Out:
# dict

# %%
df=pd.DataFrame(a)
df
# Out:
#    Emp_ID    Name Department  Salary
# 0       1     sam         IT   20000
# 1       2   mohit      Sales   25000
# 2       3     raj         IT   30000
# 3       4   Rahul         IT   31000
# 4       5  Aniket      Sales   26000

# %%
# Export this data into csv

# %%
df.to_csv("Emp_data.csv")

# %%
# Export this data into Excel

# %%
df.to_excel("New_emp_data.xlsx")

# %%
# inport the data

# %%
a=pd.read_csv("/content/Emp_data.csv")
a
# Out:
#    Unnamed: 0  Emp_ID    Name Department  Salary
# 0           0       1     sam         IT   20000
# 1           1       2   mohit      Sales   25000
# 2           2       3     raj         IT   30000
# 3           3       4   Rahul         IT   31000
# 4           4       5  Aniket      Sales   26000

# %%
b=pd.read_csv("/content/Phonedata.csv")

b.head(5)
# Out:
#                                 Phone Name  Rating                 Storage  \
# 0    OnePlus 13s 5G (Black Velvet, 256 GB)     4.6  12 GB RAM | 256 GB ROM
# 1      OnePlus 9 5G (Astral Black, 128 GB)     3.8   8 GB RAM | 128 GB ROM
# 2      OnePlus 13s 5G (Green Silk, 256 GB)     4.6  12 GB RAM | 256 GB ROM
# 3  OnePlus 15R 5G (Charcoal Black, 256 GB)     4.6  12 GB RAM | 256 GB ROM
# 4      OnePlus 13s 5G (Pink Satin, 256 GB)     4.6  12 GB RAM | 256 GB ROM
#
#                         Display          DTBslk 3           Battery  \
# 0  16.05 cm (6.32 inch) Display  50MP Rear Camera  5850 mAh Battery
# 1  16.64 cm (6.55 inch) Display  48MP Rear Camera  4500 mAh Battery
# 2  16.05 cm (6.32 inch) Display  50MP Rear Camera  5850 mAh Battery
# 3  17.35 cm (6.83 inch) Display  50MP Rear Camera  7400 mAh Battery
# 4  16.05 cm (6.32 inch) Display  50MP Rear Camera  5850 mAh Battery
#
#                                              Guarnty off_price Actual price  \
# ...
