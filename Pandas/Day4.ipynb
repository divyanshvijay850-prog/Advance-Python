# %%
import pandas as pd

# %%
df=pd.read_csv("/content/placement - placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.info()  # data type infromation
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df=df.iloc[:4,:3]  # iloc[row_range  , cloumn_range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3,['cgpa','placed']]   # low [low_range, column_range]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
s=df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p=df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
df['cgpa'].dtype
# Out:
# dtype('float64')

# %%
b=df.empty   # it returns true if there any missing data in dataframe otherwise return false

b
# Out:
# False

# %%
df.isnull().sum()  ## for checking missing values
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df=df.dropna()  # for remove missing row

# %%
i=df.ndim   # number od axes(it is 2)
i
# Out:
# 2

# %%
t=df.shape    # shape=n(rows) ,n(columns)
t
df.shape[0]    # total rows in data

df.shape[1]   # total columns in data
# Out:
# 3

# %%
d=df.size     # row count*column count
d
# Out:
# 300

# %%
a=df.values     # get a numpy array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df=df.copy()

# %%
p=df.sort_values(by='resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/tips - tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# tips data set
# categorical column--- numberical column convert using map()
# rows,column, loc,iloc,1column sort

# %%
df['sex'] = df['sex'].map({'Female': 1,'Male':0})
df.head(5)
# Out:
#    total_bill   tip  sex smoker  day    time  size
# 0       16.99  1.01    1     No  Sun  Dinner     2
# 1       10.34  1.66    0     No  Sun  Dinner     3
# 2       21.01  3.50    0     No  Sun  Dinner     3
# 3       23.68  3.31    0     No  Sun  Dinner     2
# 4       24.59  3.61    1     No  Sun  Dinner     4

# %%
df['smoker']= df['smoker'].map({'No': 0, 'Yes': 1})
df.head(5)
# Out:
#    total_bill   tip  sex  smoker  day    time  size
# 0       16.99  1.01    1       0  Sun  Dinner     2
# 1       10.34  1.66    0       0  Sun  Dinner     3
# 2       21.01  3.50    0       0  Sun  Dinner     3
# 3       23.68  3.31    0       0  Sun  Dinner     2
# 4       24.59  3.61    1       0  Sun  Dinner     4

# %%
df['day']=df['day'].map({'Sun':0,'Mon':1,'Thu':2,'Wed':3,'Thur':4,'Fri':5,'Sat':6})
df.head(5)
# Out:
#    total_bill   tip  sex  smoker  day    time  size
# 0       16.99  1.01    1       0    0  Dinner     2
# 1       10.34  1.66    0       0    0  Dinner     3
# 2       21.01  3.50    0       0    0  Dinner     3
# 3       23.68  3.31    0       0    0  Dinner     2
# 4       24.59  3.61    1       0    0  Dinner     4

# %%
df['time']=df['time'].map({'Dinner':1,'Lunch':2})
df.head(5)
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    1       0    0     1     2
# 1       10.34  1.66    0       0    0     1     3
# 2       21.01  3.50    0       0    0     1     3
# 3       23.68  3.31    0       0    0     1     2
# 4       24.59  3.61    1       0    0     1     4

# %%
df.shape
# Out:
# (244, 7)

# %%
df_iloc=df.iloc[:3,:7]
df_iloc
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    1       0    0     1     2
# 1       10.34  1.66    0       0    0     1     3
# 2       21.01  3.50    0       0    0     1     3

# %%
df.sort_values(by="size")
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 82        10.07  1.83    1       0    4     2     1
# 111        7.25  1.00    1       0    6     1     1
# 67         3.07  1.00    1       1    6     1     1
# 222        8.58  1.92    0       1    5     2     1
# 12        15.42  1.57    0       0    0     1     2
# ..          ...   ...  ...     ...  ...   ...   ...
# 185       20.69  5.00    0       0    0     1     5
# 125       29.80  4.20    1       0    4     2     6
# 143       27.05  5.00    1       0    4     2     6
# 156       48.17  5.00    0       0    0     1     6
# 141       34.30  6.70    0       0    4     2     6
#
# [244 rows x 7 columns]
